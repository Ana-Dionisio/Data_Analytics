# %% [markdown]
# Sprint 12
#
# Aplicarás lo aprendido sobre APIs REST, métodos HTTP y códigos de estado, utilizando APIs públicas para consultar datos, filtrarlos y finalmente guardarlos en un DataFrame de pandas.

# %% [markdown]
# Nivel 1
#
# Desde un Jupyter Notebook realizarás los siguientes ejercicios utilizando la librería requests de Python.

# %%
### Installs

# %pip install requests

# %%
### Imports

import requests
from requests.exceptions import HTTPError
import pprint
from pprint import pprint
import pandas as pd

# %% [markdown]
# 1. Consulta la API pública JSONPlaceholder utilizando el método GET para obtener:
#
# Lista de publicaciones (/posts)
# Lista de usuarios (/users)
# Lista de tareas (/todos)

# %%
requests.get('https://jsonplaceholder.typicode.com/')
# Out:
# <Response [200]>

# %%
## function for getting API data

def get_api_data(url, list):
    
    consult = url + list

    response = requests.get(consult)

    if response:
        
        return response.json()
    else:
       print(f'Error retrieving data {response.status_code}')

# %%
# objects and function call

url = 'https://jsonplaceholder.typicode.com'
list = '/posts'

get_api_data(url, list)
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
# objects and function call

url = 'https://jsonplaceholder.typicode.com'
list = '/users'

get_api_data(url, list)
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
# ...

# %%
# objects and function call

url = 'https://jsonplaceholder.typicode.com'
list = '/todos'

get_api_data(url, list)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %% [markdown]
# 2. Muestra por pantalla:
#
# La cantidad total de cada recurso.
# El código de estado de cada petición.

# %%
# function for retrieving the quantity and the request status code

def get_api_quantity(list):
    
    url = 'https://jsonplaceholder.typicode.com' + list

    response = requests.get(url)

    if response:
        data = response.json()
        message = print(f'Total {list}: {len(data)} and Status code: {response.status_code}')
        #pprint(f'Status code {list}: {response.status_code}')
    else:
        message = print(f'Error retrieving data from "{list}". Status code: {response.status_code}')
    
    return message

# %%
# function call

get_api_quantity('/posts')
get_api_quantity('/users')
get_api_quantity('/todos')
# Out:
# Total /posts: 100 and Status code: 200
# Total /users: 10 and Status code: 200
# Total /todos: 200 and Status code: 200

# %% [markdown]
# 3. Realiza una petición a una publicación inexistente para obtener un error 404 y muestra el código de estado recibido.

# %%
# function call

get_api_quantity('/all')
# Out:
# Error retrieving data from "/all". Status code: 404

# %% [markdown]
# 4. Realiza una petición POST para crear una nueva publicación ficticia. Incluye el título, el cuerpo del mensaje y un userId.
#
# Muestra la respuesta JSON.
# Muestra el código de estado.

# %%
# function for creating a API posting

def post_data(mypost):
        url = 'https://jsonplaceholder.typicode.com/posts'

        response = requests.post(url, json = mypost)

        if response:
               message = print(f'Success posting data! Status code: {response.status_code}')
                
        else:
                message = print(f'Error posting data to {url}". Status code: {response.status_code}')
        
        return message, response.json()

# %%
# object and funtion call

mypost = {"userId":600,
      "title":"title test sprint 12 data analytics",
      "body":"body test sprint 12 data analytics"}

post_data(mypost)
# Out:
# Success posting data! Status code: 201
# (None,
#  {'userId': 600,
#   'title': 'title test sprint 12 data analytics',
#   'body': 'body test sprint 12 data analytics',
#   'id': 101})

# %% [markdown]
# 5. Realiza una petición PATCH para modificar parcialmente una publicación existente.
#
# Muestra la respuesta JSON.  Muestra el código de estado.

# %%
# function for patching a API posting

def pathc_data(post_id, myupdate):
        
        url = 'https://jsonplaceholder.typicode.com/posts/' + post_id

        response = requests.patch(url, json = myupdate)

        if response:
               message = print(f'Success patching data! Status code: {response.status_code}')
                
        else:
                message = print(f'Error pathing data to {url}". Status code: {response.status_code}')
        
        return message, response.json()

# %%
# object and function call 

mypost = {'title': 'Updated title via PATCH'}
id = '501'
pathc_data(id, mypost)
# Out:
# Success patching data! Status code: 200
# (None, {'title': 'Updated title via PATCH'})

# %% [markdown]
# 6. Haz una petición DELETE sobre una publicación.
#
# Muestra la respuesta JSON.
# Muestra el código de estado.

# %%
# function for deleting  a API posting

def delete_data(post_id):
        
        url = 'https://jsonplaceholder.typicode.com/posts/' + post_id

        response = requests.delete(url)

        if response:
               message = print(f'Success deleting data! Status code: {response.status_code}')
                
        else:
                message = print(f'Error deleting data. Post id {post_id}". Status code: {response.status_code}')
        
        return message, response.json()

# %%
# object and function call

id = '501'
delete_data(id)
# Out:
# Success deleting data! Status code: 200
# (None, {})

# %% [markdown]
# Nivel 2
# Interacción con una API pública real
# 1. Explora el repositorio de Public APIs y elige una API que permita realizar peticiones GET.
#
# Response:  https://api.generadordni.es

# %% [markdown]
# 2. Lee la documentación de la API:
#
# Revisa la sección de endpoints disponibles. En un markdown, apunta al menos dos endpoints diferentes.
# Comprueba si ofrece filtros o parámetros opcionales interesantes. En un markdown, anótalos.
# Verifica que la respuesta sea en formato JSON (es el más adecuado para este ejercicio).

# %% [markdown]
# En un markdown, apunta al menos dos endpoints diferentes.
#
# person = https://api.generadordni.es/v2/profiles/person
# company = https://api.generadordni.es/v2/profiles/company

# %% [markdown]
# Comprueba si ofrece filtros o parámetros opcionales interesantes. En un markdown, anótalos.
#
# person: (examples)
# ?results=2&gender=male
# ?results=5&include_fields=nif,fullname,phonenumber
#
# company: (examples)
# ?results=1&exclude_fields=cnae,activity,creation_date,faxnumber

# %% [markdown]
# Verifica que la respuesta sea en formato JSON (es el más adecuado para este ejercicio).
#
# https://api.generadordni.es/api-docs/#/profiles/get_profiles_person
# Response code 200 Operación correcta
# Media type - application/json
#
# curl -X 'GET' \
#   'https://api.generadordni.es/v2/profiles/company?results=3' \
#   -H 'accept: application/json'

# %% [markdown]
# 3. Haz una petición GET sencilla:
#
# Muestra el código de estado de la respuesta.
# Imprime de forma clara algunos de los campos de la respuesta JSON

# %%
requests.get('https://api.generadordni.es/v2/profiles/person')
# Out:
# <Response [429]>

# %%
# object and function call

url = 'https://api.generadordni.es/v2/profiles/person'
list = '?results=2&gender=female'

get_api_data(url, list)
# Out:
# Error retrieving data 429

# %%
# object and function call

url = 'https://api.generadordni.es/v2/profiles'
list = '/person?results=50&gender=female'

get_api_data(url, list) 

# error 429 - "error": "You have exceeded the 10 requests today!"
# Out:
# Error retrieving data 429

# %% [markdown]
# 4. Convierte los datos a un DataFrame de pandas:
#
# Muestra las primeras filas de DataFrame.

# %%
# objects and function call

url = 'https://api.generadordni.es/v2/profiles'
list = '/person?results=50&gender=female'

data = get_api_data(url, list)

# converting the result into a dataframe 
df = pd.DataFrame(data)

df.head()
# Out:
# Error retrieving data 429
# Empty DataFrame
# Columns: []
# Index: []

# %%
## I'm doint the nº 4 request wiht this url as the one I chose has reached its daily request limit

url = 'https://jsonplaceholder.typicode.com'
list = '/todos'

data = get_api_data(url, list)

df = pd.DataFrame(data)

df.head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# Nivel 3
# API de Open Data Barcelona
# 1. Utiliza la API de Open Data BCN para:
#
# Buscar un dataset de tu interés mediante package_search y package_show. .

# %%
# function for package_search

def search_dataset(texto_busqueda):
    search = url + 'package_search'
    params = {'q': texto_busqueda}

    response = requests.get(search, params=params)
    data = response.json()

    if response.ok and data['success']:
        result= data['result']['results']
        return result
    else:
        raise Exception('Error en package_search')

# %%
# object and function call

url = 'https://opendata-ajuntament.barcelona.cat/data/api/3/action/'

result = search_dataset('bicicleta')
print(f'Datasets founds: {len(result)}')
for r in result[:5]:
    print('-', r['title'])
# Out:
# Datasets founds: 5
# - Friends of the Bike buildings of the public facilities of the city of Barcelona
# - Bike corridors of the city of Barcelona
# - Bicycle lanes of the city of Barcelona
# - Services related with bicycles in the city of Barcelona
# - Bicycles's anchorage points in the city of Barcelona

# %%
# function for package_show

def show_dataset(id):
    search = url + 'package_show'
    params = {'id': id}

    response = requests.get(search, params=params)
    data = response.json()

    if response.ok and data['success']:
        return data['result']
    else:
        raise Exception('Error en package_show')

# %%
# object and function call

selection = result[0]
detail = show_dataset(selection['id'])

print('Title:', detail['title'])
print('Description', detail['notes'])
print('Resources availables:')
for resource in detail['resources']:
    print('-', resource['name'], resource['format'], resource['url'])
# Out:
# Title: Friends of the Bike buildings of the public facilities of the city of Barcelona
# Description Public facilities of the city of Barcelona in order to promote the use of bicycles among workers. The auditees already certified or in the certification phase are published.
# Resources availables:
# - 2025_edificis_amics_bici_bcn.csv CSV https://opendata-ajuntament.barcelona.cat/data/dataset/e616872e-0a5c-4128-be15-d2e49fbd78e4/resource/66fa1382-476a-459b-b0c0-c666112d1843/download/20252_edificis_amics_bici_bcn.csv
# - 2025_edificis_amics_bici_bcn.geojson GeoJSON https://opendata-ajuntament.barcelona.cat/data/dataset/e616872e-0a5c-4128-be15-d2e49fbd78e4/resource/b49637b9-f793-464c-9acb-0ea96495379f/download/20252_edificis_amics_bici_bcn.geojson
# - 2024_edificis_amics_bici_bcn.csv CSV https://opendata-ajuntament.barcelona.cat/data/dataset/e616872e-0a5c-4128-be15-d2e49fbd78e4/resource/619097da-d196-462d-b8da-34eb0182c7bc/download/2024_edificis_amics_bici_bcn.csv
# ...

# %% [markdown]
# 2. De los resultados obtenidos, selecciona uno que tenga recursos disponibles en CSV o JSON.
#
# https://opendata-ajuntament.barcelona.cat/data/dataset/e616872e-0a5c-4128-be15-d2e49fbd78e4/resource/336ba99e-f1df-4359-8f60-4ac3db4927ec/download/2024_edificis_amics_bici_bcn_long.csv

# %% [markdown]
# 3. Con el resource_id del recurso seleccionado, realiza una consulta mediante datastore_search por:
#
# Recuperar al menos 100 registros.
#
# resource id: 336ba99e-f1df-4359-8f60-4ac3db4927ec

# %%
response = requests.get('https://opendata-ajuntament.barcelona.cat/data/api/3/action/datastore_search', params={'resource_id':'336ba99e-f1df-4359-8f60-4ac3db4927ec'})

data = response.json()

records = data['result']['records']

records
# Out:
# [{'Edifici': 'Cases Consistorials',
#   'Latitud': '41.3819',
#   'Codi_Districte': '1',
#   'Concepte': 'Any_Auditoria',
#   'X_ETRS89': '431230.34',
#   'Nom_Districte': 'Ciutat Vella',
#   'Numero_Via': '1',
#   'Nom_Barri': 'el Gòtic',
#   'Valor': '2015',
#   'Estat': 'Edifici Amic de la Bici',
#   'Y_ETRS89': '4581482.742',
#   'Codi_Barri': '2',
#   '_id': 1,
#   'Nom_Via': 'Carrer dels gegants',
#   'id': '1',
#   'Longitud': '2.1775'},
#  {'Edifici': 'Seu de Districte Gràcia',
#   'Latitud': '41.4',
#   'Codi_Districte': '6',
#   'Concepte': 'Any_Auditoria',
#   'X_ETRS89': '429602.19899999996',
#   'Nom_Districte': 'Gràcia',
#   'Numero_Via': '2',
#   'Nom_Barri': 'Vila de Gràcia',
#   'Valor': '2015',
#   'Estat': 'Edifici Amic de la Bici',
#   'Y_ETRS89': '4583505.42',
#   'Codi_Barri': '31',
#   '_id': 2,
#   'Nom_Via': 'Plaça de la Vila de Gràcia',
#   'id': '2',
#   'Longitud': '2.1578'},
#  {'Edifici': 'Oficines Diagonal 240',
#   'Latitud': '41.4044',
# ...

# %%
resource_id = '336ba99e-f1df-4359-8f60-4ac3db4927ec'

url_r_id = 'https://opendata-ajuntament.barcelona.cat/data/api/3/action/datastore_search'

params = {'resource_id': resource_id}

response = requests.get(url_r_id, params=params)
data = response.json()

records = data['result']['records']

df_resource = pd.DataFrame(records)

df_resource
# Out:
#                                            Edifici  Latitud Codi_Districte  \
# 0                              Cases Consistorials  41.3819              1
# 1                          Seu de Districte Gràcia     41.4              6
# 2                            Oficines Diagonal 240  41.4044             10
# 3                       Seu del Districte de Sants  41.3753              3
# 4                   Centre cívic cotxeres de Sants  41.3753              3
# ..                                             ...      ...            ...
# 95                 Seu de Districte de Sant Andreu  41.4359              9
# 96                                           BIMSA  41.4061             10
# 97                  Seu del Districte de Les Corts  41.3856              4
# 98  Seu annexa del Districte de Ciutat Vella / OAC  41.3841              1
# 99                                   Espai Bombers  41.3738              3
#
# ...

# %% [markdown]
# 5. Guarda DataFrame en un archivo .csv.

# %%
# storing the DataFrame in a csv file

df_resource.to_csv('Data_Frame_API.csv')
